# %%
def coordinateCvt2YOLO(size, box):
    dw = 1. / size[0]
    dh = 1. / size[1]

    # (xmin + xmax / 2)
    x = (box[0] + box[1]) / 2.0
    # (ymin + ymax / 2)
    y = (box[2] + box[3]) / 2.0

    # (xmax - xmin) = w
    w = box[1] - box[0]
    # (ymax - ymin) = h
    h = box[3] - box[2]

    x = x * dw
    w = w * dw
    y = y * dh
    h = h * dh
    return (round(x, 3), round(y, 3), round(w, 3), round(h, 3))

# %%
import os
import numpy as np
import json
from tqdm.notebook import tqdm

# %% [markdown]
# ## 파일 포맷 변경

# %%
# json_path = '/local_hdd/works/ICRyu_workspace/for_yolo/dataset/data1/label_1/nh.json'
json_path = '/local_hdd/works/ICRyu_workspace/for_yolo/dataset/data1/label_1/ai-hub.json'

# %%
# class mapping
# cls_dic = {'person_s' : 0, 'person_l' : 0, 'car' : 1, 'bicycle' : 2}
cls_dic = {'person_s' : 0, 'person_l' : 1, 'car' : 2, 'bicycle' : 3}
data = {}

with open(json_path, 'r') as f:
    json_f = json.load(f)

cnt = 0

for each_anno in json_f["annotations"]:
    for each_image in json_f["images"]:

        if each_image['id'] == each_anno['image_id']:
            img_file_path = each_image['file_name']
            img_size = (each_image['width'], each_image['height'])

    img_file_name = img_file_path.split('/')[1].split('.')[0]
    box = (each_anno['bbox'][0], each_anno['bbox'][0] + each_anno['bbox'][2], each_anno['bbox'][1], each_anno['bbox'][1] + each_anno['bbox'][3])
    box_normalized = coordinateCvt2YOLO(img_size, box)

    for each_cate in json_f["categories"]:
        if each_cate['id'] == each_anno['category_id']:
            obj_cls_name = each_cate['name']

    obj_cls = cls_dic[obj_cls_name]

    # only write person_s, person_l
    if obj_cls not in [0, 1]:
        continue

    newline = f'{obj_cls} {box_normalized[0]} {box_normalized[1]} {box_normalized[2]} {box_normalized[3]}'

    try:
        data[img_file_name].append(newline)
    except KeyError:
        data[img_file_name] = []
        cnt += 1
        data[img_file_name].append(newline)

print(cnt)
# Out:
# 14817

# %%
len(data)
# Out:
# 14817

# %%
data
# Out:
#   '0 0.465 0.181 0.043 0.361'],
#  'img_14515': ['0 0.502 0.183 0.098 0.365',
#   '1 0.404 0.401 0.22 0.123',
#   '0 0.395 0.183 0.061 0.365'],
#  'img_14514': ['1 0.405 0.401 0.222 0.123',
#   '0 0.371 0.192 0.091 0.383',
#   '0 0.512 0.185 0.112 0.37'],
#  'img_14513': ['0 0.542 0.184 0.053 0.368',
#   '0 0.359 0.19 0.075 0.379',
#   '1 0.403 0.401 0.22 0.119'],
#  'img_14512': ['0 0.569 0.189 0.111 0.378',
#   '0 0.339 0.19 0.061 0.379',
#   '1 0.404 0.402 0.221 0.125'],
#  'img_14511': ['0 0.598 0.191 0.116 0.381',
#   '1 0.403 0.404 0.221 0.127',
#   '0 0.308 0.189 0.087 0.379'],
#  'img_14510': ['1 0.404 0.403 0.221 0.123',
#   '0 0.303 0.187 0.101 0.374',
#   '0 0.626 0.191 0.066 0.382',
#   '0 0.047 0.164 0.074 0.328'],
#  'img_14509': ['0 0.282 0.189 0.076 0.379',
#   '1 0.404 0.403 0.221 0.123',
#   '0 0.654 0.191 0.074 0.382',
#   '0 0.058 0.161 0.098 0.323'],
#  'img_14508': ['1 0.404 0.401 0.224 0.118',
#   '0 0.252 0.186 0.071 0.371',
#   '0 0.678 0.193 0.118 0.387',
#   '0 0.062 0.16 0.099 0.32'],
#  'img_14507': ['1 0.404 0.401 0.219 0.121',
#   '0 0.698 0.196 0.087 0.392',
#   '0 0.226 0.188 0.116 0.376',
#   '0 0.09 0.163 0.054 0.325'],
#  'img_14506': ['1 0.411 0.398 0.224 0.108',
#   '0 0.739 0.197 0.069 0.395',
#   '0 0.221 0.188 0.096 0.376',
#   '0 0.107 0.163 0.1 0.327'],
#  'img_14505': ['1 0.405 0.403 0.22 0.122',
#   '0 0.117 0.166 0.109 0.333',
#   '0 0.185 0.187 0.063 0.373',
#   '0 0.762 0.206 0.127 0.412'],
#  'img_14504': ['1 0.404 0.404 0.22 0.122',
#   '0 0.163 0.191 0.086 0.371',
#   '0 0.779 0.211 0.129 0.422'],
#  'img_14503': ['0 0.154 0.186 0.094 0.373',
#   '0 0.812 0.208 0.057 0.416',
#   '1 0.405 0.404 0.217 0.121'],
#  'img_14502': ['1 0.403 0.403 0.218 0.123',
#   '0 0.842 0.217 0.098 0.407',
#   '0 0.131 0.185 0.08 0.369',
#   '0 0.197 0.167 0.095 0.334'],
#  'img_14501': ['1 0.405 0.404 0.218 0.132',
#   '0 0.105 0.183 0.064 0.367',
#   '0 0.199 0.169 0.094 0.338',
#   '0 0.861 0.234 0.131 0.407'],
#  'img_14500': ['1 0.405 0.401 0.217 0.123',
#   '0 0.89 0.23 0.089 0.412',
#   '0 0.088 0.185 0.096 0.37',
#   '0 0.232 0.171 0.064 0.341'],
#  'img_14499': ['0 0.932 0.237 0.085 0.417',
#   '1 0.405 0.399 0.217 0.13',
#   '0 0.253 0.175 0.115 0.349',
#   '0 0.085 0.181 0.095 0.362'],
#  'img_14498': ['0 0.942 0.247 0.117 0.429',
#   '1 0.407 0.398 0.215 0.13',
#   '0 0.266 0.176 0.116 0.352',
#   '0 0.058 0.182 0.076 0.364'],
#  'img_14497': ['1 0.411 0.395 0.224 0.114',
#   '0 0.293 0.175 0.064 0.35',
#   '0 0.035 0.183 0.07 0.366',
#   '0 0.962 0.245 0.076 0.434'],
#  'img_14496': ['0 0.324 0.175 0.083 0.349',
#   '0 0.034 0.179 0.065 0.357',
#   '1 0.406 0.392 0.224 0.108'],
#  'img_14495': ['0 0.341 0.178 0.103 0.355', '1 0.393 0.384 0.201 0.139'],
#  'img_14494': ['0 0.361 0.174 0.062 0.348', '0 0.378 0.36 0.143 0.189'],
#  'img_14493': ['0 0.364 0.352 0.115 0.2', '0 0.371 0.144 0.091 0.287'],
#  'img_14492': ['0 0.354 0.361 0.118 0.199', '0 0.399 0.19 0.132 0.379'],
#  'img_14491': ['0 0.422 0.19 0.119 0.38', '0 0.346 0.353 0.138 0.207'],
#  'img_14490': ['0 0.461 0.19 0.068 0.379', '0 0.331 0.329 0.126 0.227'],
#  'img_14150': ['0 0.164 0.186 0.088 0.357',
#   '0 0.11 0.232 0.081 0.408',
#   '0 0.744 0.143 0.059 0.286'],
#  'img_14149': ['0 0.737 0.142 0.073 0.285',
#   '0 0.168 0.177 0.088 0.353',
#   '0 0.116 0.233 0.088 0.413'],
#  'img_14148': ['0 0.123 0.23 0.102 0.407',
#   '0 0.734 0.141 0.069 0.281',
#   '0 0.168 0.177 0.088 0.353'],
#  'img_14147': ['0 0.168 0.177 0.088 0.353',
#   '0 0.731 0.145 0.073 0.29',
#   '0 0.13 0.232 0.126 0.407'],
#  'img_14146': ['0 0.13 0.233 0.119 0.413',
#   '0 0.731 0.141 0.07 0.281',
#   '0 0.168 0.177 0.088 0.353'],
#  'img_14145': ['0 0.72 0.15 0.063 0.301',
#   '0 0.131 0.233 0.12 0.409',
#   '0 0.168 0.177 0.088 0.353',
#   '0 0.956 0.329 0.088 0.467'],
#  'img_14144': ['0 0.705 0.142 0.064 0.283',
#   '0 0.168 0.177 0.088 0.353',
#   '0 0.936 0.339 0.129 0.466',
#   '0 0.13 0.233 0.113 0.413'],
#  'img_14143': ['0 0.128 0.232 0.115 0.404',
#   '0 0.913 0.335 0.106 0.476',
#   '0 0.693 0.145 0.081 0.29',
#   '0 0.168 0.177 0.088 0.353'],
#  'img_14142': ['0 0.168 0.177 0.088 0.353',
#   '0 0.69 0.142 0.081 0.285',
#   '0 0.128 0.229 0.117 0.409',
#   '0 0.877 0.341 0.109 0.48'],
#  'img_14141': ['0 0.125 0.231 0.113 0.416',
#   '0 0.168 0.177 0.088 0.353',
#   '0 0.837 0.347 0.153 0.464',
#   '0 0.675 0.146 0.056 0.292'],
#  'img_14140': ['0 0.168 0.177 0.088 0.353',
#   '0 0.818 0.347 0.133 0.478',
#   '0 0.671 0.148 0.058 0.295',
#   '0 0.122 0.23 0.106 0.404'],
#  'img_14139': ['0 0.168 0.177 0.088 0.353',
#   '0 0.168 0.177 0.088 0.353',
#   '0 0.112 0.227 0.089 0.413',
#   '0 0.665 0.151 0.072 0.303',
#   '0 0.787 0.347 0.106 0.478'],
#  'img_14138': ['0 0.728 0.344 0.149 0.455',
#   '0 0.653 0.155 0.066 0.31',
#   '0 0.11 0.233 0.082 0.416',
#   '0 0.169 0.173 0.088 0.346'],
#  'img_14137': ['0 0.109 0.231 0.08 0.405',
#   '0 0.647 0.151 0.053 0.303',
#   '0 0.704 0.342 0.1 0.482',
#   '0 0.168 0.186 0.088 0.349'],
#  'img_14136': ['0 0.112 0.226 0.088 0.413',
#   '0 0.168 0.18 0.088 0.36',
#   '0 0.657 0.343 0.119 0.45'],
#  'img_14135': ['0 0.62 0.351 0.139 0.437',
#   '0 0.11 0.226 0.087 0.414',
#   '0 0.168 0.18 0.088 0.36'],
#  'img_14134': ['0 0.634 0.154 0.05 0.308',
#   '0 0.112 0.233 0.086 0.402',
#   '0 0.603 0.338 0.115 0.464',
#   '0 0.168 0.18 0.088 0.36'],
#  'img_14133': ['0 0.543 0.34 0.094 0.453',
#   '0 0.168 0.18 0.088 0.36',
#   '0 0.11 0.231 0.085 0.398',
#   '0 0.621 0.155 0.07 0.31'],
#  'img_14132': ['0 0.612 0.16 0.077 0.317',
#   '0 0.113 0.228 0.086 0.407',
#   '0 0.516 0.348 0.144 0.434',
#   '0 0.168 0.178 0.088 0.357'],
#  'img_14131': ['0 0.168 0.178 0.088 0.356',
#   '0 0.112 0.234 0.091 0.404',
#   '0 0.496 0.335 0.12 0.48',
#   '0 0.614 0.16 0.08 0.32'],
#  'img_14130': ['0 0.168 0.171 0.088 0.342',
#   '0 0.612 0.157 0.083 0.315',
#   '0 0.432 0.333 0.107 0.46',
#   '0 0.113 0.231 0.079 0.405'],
#  'img_14129': ['0 0.168 0.171 0.088 0.342',
#   '0 0.117 0.232 0.08 0.404',
#   '0 0.608 0.163 0.085 0.326',
#   '0 0.412 0.342 0.146 0.453'],
#  'img_14128': ['0 0.596 0.163 0.066 0.326',
#   '0 0.388 0.338 0.108 0.464',
#   '0 0.168 0.171 0.088 0.342',
#   '0 0.118 0.231 0.072 0.42'],
#  'img_14127': ['0 0.341 0.339 0.07 0.473',
#   '0 0.168 0.171 0.088 0.342',
#   '0 0.116 0.232 0.071 0.407',
#   '0 0.585 0.164 0.052 0.327'],
#  'img_14126': ['0 0.576 0.168 0.062 0.336',
#   '0 0.31 0.343 0.132 0.464',
#   '0 0.12 0.235 0.078 0.404',
#   '0 0.168 0.171 0.088 0.342'],
#  'img_14125': ['0 0.573 0.167 0.063 0.334',
#   '0 0.122 0.235 0.077 0.397',
#   '0 0.303 0.338 0.111 0.475',
#   '0 0.168 0.171 0.088 0.342'],
#  'img_14124': ['0 0.256 0.334 0.066 0.466',
#   '0 0.168 0.171 0.088 0.342',
#   '0 0.57 0.168 0.061 0.336',
#   '0 0.119 0.235 0.073 0.397'],
#  'img_14123': ['0 0.168 0.171 0.088 0.342',
#   '0 0.227 0.336 0.117 0.439',
#   '0 0.116 0.241 0.073 0.391',
#   '0 0.56 0.168 0.062 0.336'],
#  'img_14122': ['0 0.168 0.171 0.088 0.342',
#   '0 0.205 0.343 0.137 0.443',
#   '0 0.549 0.167 0.059 0.334',
#   '0 0.115 0.242 0.082 0.39'],
#  'img_14121': ['0 0.168 0.171 0.088 0.342',
#   '0 0.161 0.337 0.07 0.466',
#   '0 0.112 0.242 0.077 0.39',
#   '0 0.535 0.172 0.08 0.343'],
#  'img_14120': ['0 0.131 0.34 0.102 0.45',
#   '0 0.168 0.171 0.088 0.342',
#   '0 0.529 0.17 0.096 0.34'],
#  'img_14119': ['0 0.523 0.178 0.085 0.349',
#   '0 0.112 0.343 0.125 0.443',
#   '0 0.168 0.171 0.088 0.342'],
#  'img_14118': ['0 0.168 0.171 0.088 0.342',
#   '0 0.508 0.175 0.073 0.35',
#   '0 0.106 0.329 0.112 0.453'],
#  'img_14117': ['0 0.484 0.179 0.064 0.357',
#   '0 0.168 0.171 0.088 0.342',
#   '0 0.128 0.241 0.07 0.382',
#   '0 0.071 0.326 0.07 0.453'],
#  'img_14116': ['0 0.058 0.32 0.07 0.453',
#   '0 0.47 0.175 0.081 0.35',
#   '0 0.127 0.244 0.076 0.372',
#   '0 0.168 0.171 0.088 0.342'],
#  'img_14115': ['0 0.058 0.32 0.07 0.453',
#   '0 0.468 0.179 0.083 0.357',
#   '0 0.168 0.171 0.088 0.342',
#   '0 0.125 0.243 0.081 0.377'],
#  'img_14114': ['0 0.054 0.322 0.07 0.453',
#   '0 0.168 0.171 0.088 0.342',
#   '0 0.46 0.174 0.072 0.349',
#   '0 0.12 0.247 0.08 0.363'],
#  'img_14113': ['0 0.123 0.256 0.09 0.367',
#   '0 0.054 0.322 0.07 0.453',
#   '0 0.168 0.171 0.088 0.342',
#   '0 0.437 0.175 0.055 0.34'],
#  'img_14112': ['0 0.168 0.171 0.088 0.342',
#   '0 0.423 0.176 0.073 0.352',
#   '0 0.112 0.266 0.081 0.356',
#   '0 0.054 0.322 0.07 0.453'],
#  'img_14111': ['0 0.168 0.171 0.088 0.342',
#   '0 0.113 0.272 0.085 0.322',
#   '0 0.417 0.176 0.075 0.352',
#   '0 0.054 0.322 0.07 0.453'],
#  'img_14110': ['0 0.168 0.172 0.088 0.344',
#   '0 0.054 0.322 0.07 0.453',
#   '0 0.117 0.287 0.095 0.301',
#   '0 0.407 0.166 0.07 0.333'],
#  'img_14109': ['0 0.116 0.31 0.089 0.259',
#   '0 0.169 0.172 0.088 0.344',
#   '0 0.054 0.322 0.07 0.453',
#   '0 0.391 0.173 0.067 0.347'],
#  'img_14108': ['0 0.054 0.322 0.07 0.453',
#   '0 0.126 0.319 0.087 0.23',
#   '0 0.17 0.172 0.088 0.344',
#   '0 0.378 0.166 0.067 0.333'],
#  'img_14107': ['0 0.374 0.165 0.075 0.329',
#   '0 0.125 0.333 0.087 0.23',
#   '0 0.173 0.173 0.088 0.346',
#   '0 0.054 0.322 0.07 0.453'],
#  'img_14106': ['0 0.367 0.167 0.087 0.334',
#   '0 0.165 0.174 0.088 0.348',
#   '0 0.132 0.327 0.087 0.23',
#   '0 0.054 0.322 0.07 0.453'],
#  'img_14105': ['0 0.164 0.173 0.088 0.346',
#   '0 0.348 0.165 0.06 0.329',
#   '0 0.054 0.322 0.07 0.453',
#   '0 0.126 0.327 0.087 0.23'],
#  'img_14104': ['0 0.331 0.16 0.06 0.32',
#   '0 0.126 0.327 0.087 0.23',
#   '0 0.164 0.177 0.088 0.349',
#   '0 0.054 0.322 0.07 0.453'],
#  'img_14103': ['0 0.319 0.161 0.072 0.322',
#   '0 0.161 0.184 0.088 0.349',
#   '0 0.126 0.327 0.087 0.23',
#   '0 0.054 0.324 0.07 0.453'],
#  'img_14102': ['0 0.161 0.182 0.088 0.349',
#   '0 0.054 0.324 0.07 0.453',
#   '0 0.125 0.324 0.087 0.23',
#   '0 0.31 0.162 0.08 0.324'],
#  'img_14101': ['0 0.054 0.324 0.07 0.453',
#   '0 0.125 0.324 0.087 0.23',
#   '0 0.158 0.179 0.088 0.349',
#   '0 0.294 0.161 0.069 0.323'],
#  'img_14100': ['0 0.125 0.324 0.087 0.23',
#   '0 0.277 0.157 0.084 0.31',
#   '0 0.054 0.324 0.07 0.453',
#   '0 0.156 0.174 0.088 0.348'],
#  'img_14099': ['0 0.266 0.152 0.084 0.303',
#   '0 0.054 0.324 0.07 0.453',
#   '0 0.125 0.324 0.087 0.23',
#   '0 0.158 0.174 0.088 0.348'],
#  'img_14098': ['0 0.158 0.174 0.088 0.348',
#   '0 0.055 0.333 0.07 0.453',
#   '0 0.125 0.324 0.087 0.23',
#   '0 0.26 0.155 0.084 0.31'],
#  'img_14097': ['0 0.055 0.333 0.07 0.453',
#   '0 0.24 0.157 0.072 0.315',
#   '0 0.158 0.174 0.088 0.348',
#   '0 0.126 0.324 0.087 0.23'],
#  'img_14096': ['0 0.236 0.152 0.055 0.304',
#   '0 0.056 0.32 0.07 0.453',
#   '0 0.125 0.317 0.087 0.23',
#   '0 0.159 0.174 0.088 0.348'],
#  'img_14095': ['0 0.219 0.157 0.064 0.315',
#   '0 0.127 0.322 0.087 0.23',
#   '0 0.159 0.174 0.088 0.348',
#   '0 0.058 0.331 0.085 0.457'],
#  'img_14094': ['0 0.068 0.331 0.115 0.464',
#   '0 0.159 0.174 0.088 0.348',
#   '0 0.127 0.322 0.087 0.23'],
#  'img_14093': ['0 0.084 0.331 0.145 0.464',
#   '0 0.159 0.174 0.088 0.348',
#   '0 0.127 0.322 0.087 0.23'],
#  'img_14092': ['0 0.084 0.331 0.145 0.464',
#   '0 0.159 0.174 0.088 0.348',
#   '0 0.127 0.322 0.087 0.23'],
#  'img_14091': ['0 0.127 0.322 0.087 0.23',
#   '0 0.159 0.174 0.088 0.348',
#   '0 0.084 0.331 0.145 0.464'],
#  'img_14090': ['0 0.127 0.322 0.087 0.23',
#   '0 0.159 0.174 0.088 0.348',
#   '0 0.084 0.331 0.145 0.464'],
#  'img_14089': ['0 0.127 0.322 0.087 0.23',
#   '0 0.084 0.331 0.145 0.464',
#   '0 0.159 0.174 0.088 0.348'],
#  'img_14088': ['0 0.128 0.319 0.087 0.23',
#   '0 0.084 0.326 0.145 0.464',
#   '0 0.159 0.174 0.088 0.349'],
#  'img_14087': ['0 0.084 0.321 0.144 0.448',
#   '0 0.123 0.317 0.08 0.23',
#   '0 0.158 0.174 0.09 0.349'],
#  'img_14086': ['0 0.156 0.174 0.086 0.349',
#   '0 0.084 0.328 0.14 0.459',
#   '0 0.124 0.321 0.08 0.225'],
#  'img_14085': ['0 0.157 0.178 0.086 0.356',
#   '0 0.086 0.329 0.142 0.46',
#   '0 0.123 0.324 0.079 0.227'],
#  'img_14084': ['0 0.082 0.332 0.149 0.455',
#   '0 0.159 0.177 0.083 0.354',
#   '0 0.123 0.326 0.081 0.232'],
#  'img_14083': ['0 0.157 0.176 0.085 0.345',
#   '0 0.127 0.323 0.088 0.228',
#   '0 0.083 0.321 0.147 0.444'],
#  'img_14082': ['0 0.084 0.33 0.148 0.455',
#   '0 0.156 0.178 0.092 0.356',
#   '0 0.124 0.326 0.079 0.23'],
#  'img_14081': ['0 0.125 0.316 0.091 0.246',
#   '0 0.086 0.326 0.143 0.448',
#   '0 0.156 0.178 0.087 0.356'],
#  'img_14080': ['0 0.121 0.319 0.085 0.239',
#   '0 0.086 0.328 0.145 0.455',
#   '0 0.156 0.176 0.085 0.352'],
#  'img_14079': ['0 0.157 0.179 0.088 0.357',
#   '0 0.121 0.317 0.097 0.237',
#   '0 0.085 0.329 0.143 0.45'],
#  'img_14078': ['0 0.084 0.323 0.141 0.455',
#   '0 0.158 0.171 0.091 0.342',
#   '0 0.12 0.314 0.094 0.236'],
#  'img_14077': ['0 0.12 0.314 0.095 0.253',
#   '0 0.082 0.332 0.146 0.455',
#   '0 0.157 0.176 0.09 0.352'],
#  'img_14076': ['0 0.081 0.326 0.14 0.455',
#   '0 0.122 0.321 0.099 0.239',
#   '0 0.156 0.176 0.094 0.352'],
#  'img_14075': ['0 0.082 0.331 0.144 0.46',
#   '0 0.12 0.325 0.096 0.232',
#   '0 0.155 0.179 0.083 0.357'],
#  'img_14074': ['0 0.081 0.326 0.142 0.45',
#   '0 0.159 0.176 0.093 0.352',
#   '0 0.119 0.322 0.099 0.216'],
#  'img_14073': ['0 0.119 0.328 0.103 0.218',
#   '0 0.084 0.328 0.145 0.462',
#   '0 0.158 0.173 0.082 0.345'],
#  'img_14072': ['0 0.122 0.326 0.107 0.221',
#   '0 0.158 0.176 0.088 0.352',
#   '0 0.078 0.324 0.138 0.464'],
#  'img_14071': ['0 0.162 0.175 0.089 0.35',
#   '0 0.082 0.329 0.145 0.464',
#   '0 0.12 0.328 0.098 0.211'],
#  'img_14070': ['0 0.119 0.327 0.096 0.209',
#   '0 0.159 0.17 0.089 0.34',
#   '0 0.084 0.322 0.145 0.457'],
#  'img_14069': ['0 0.117 0.33 0.104 0.211',
#   '0 0.159 0.179 0.094 0.357',
#   '0 0.087 0.33 0.145 0.466'],
#  'img_14068': ['0 0.119 0.326 0.109 0.225',
#   '0 0.156 0.177 0.092 0.354',
#   '0 0.084 0.321 0.144 0.462'],
#  'img_14067': ['0 0.12 0.329 0.11 0.223',
#   '0 0.161 0.176 0.093 0.352',
#   '0 0.087 0.324 0.146 0.46'],
#  'img_14066': ['0 0.085 0.331 0.142 0.471',
#   '0 0.115 0.311 0.104 0.259',
#   '0 0.159 0.174 0.093 0.349'],
#  'img_14065': ['0 0.111 0.299 0.092 0.259',
#   '0 0.15 0.168 0.088 0.336',
#   '0 0.071 0.32 0.129 0.471'],
#  'img_14064': ['0 0.115 0.311 0.103 0.246',
#   '0 0.069 0.319 0.118 0.478',
#   '0 0.152 0.165 0.093 0.331'],
#  'img_14063': ['0 0.057 0.324 0.093 0.457',
#   '0 0.128 0.326 0.112 0.243',
#   '0 0.155 0.171 0.094 0.342'],
#  'img_14062': ['0 0.162 0.188 0.086 0.375',
#   '0 0.049 0.317 0.074 0.475',
#   '0 0.133 0.319 0.11 0.228'],
#  'img_14061': ['0 0.045 0.318 0.073 0.466',
#   '0 0.168 0.187 0.089 0.373',
#   '0 0.138 0.325 0.115 0.214'],
#  'img_14060': ['0 0.174 0.189 0.084 0.379',
#   '0 0.139 0.324 0.121 0.212',
#   '0 0.049 0.316 0.074 0.473'],
#  'img_14059': ['0 0.05 0.314 0.074 0.476',
#   '0 0.175 0.173 0.08 0.345',
#   '0 0.143 0.326 0.121 0.225'],
#  'img_14058': ['0 0.051 0.314 0.07 0.483',
#   '0 0.14 0.323 0.123 0.218',
#   '0 0.181 0.168 0.078 0.336'],
#  'img_14057': ['0 0.185 0.178 0.087 0.356',
#   '0 0.136 0.325 0.114 0.221',
#   '0 0.05 0.311 0.074 0.476'],
#  'img_14056': ['0 0.182 0.176 0.086 0.352',
#   '0 0.135 0.324 0.117 0.216',
#   '0 0.05 0.319 0.074 0.485'],
#  'img_14055': ['0 0.047 0.316 0.083 0.48',
#   '0 0.132 0.324 0.115 0.212',
#   '0 0.199 0.181 0.088 0.363'],
#  'img_14054': ['0 0.127 0.321 0.111 0.214',
#   '0 0.212 0.183 0.089 0.366',
#   '0 0.039 0.321 0.079 0.476'],
#  'img_14053': ['0 0.219 0.183 0.081 0.366',
#   '0 0.125 0.319 0.107 0.225',
#   '0 0.04 0.327 0.08 0.475'],
#  'img_14052': ['0 0.234 0.179 0.081 0.357',
#   '0 0.126 0.304 0.101 0.262',
#   '0 0.038 0.327 0.076 0.478'],
#  'img_14051': ['0 0.247 0.183 0.082 0.366',
#   '0 0.125 0.289 0.094 0.296',
#   '0 0.036 0.331 0.072 0.467'],
#  'img_14050': ['0 0.257 0.184 0.097 0.368',
#   '0 0.117 0.278 0.084 0.322',
#   '0 0.028 0.33 0.057 0.466'],
#  'img_14049': ['0 0.27 0.178 0.088 0.356',
#   '0 0.133 0.265 0.096 0.328',
#   '0 0.028 0.336 0.056 0.453'],
#  'img_14048': ['0 0.294 0.178 0.092 0.356',
#   '0 0.133 0.263 0.094 0.338',
#   '0 0.035 0.366 0.071 0.393'],
#  'img_14047': ['0 0.305 0.181 0.098 0.363',
#   '0 0.128 0.262 0.09 0.322',
#   '0 0.036 0.39 0.073 0.345'],
#  'img_14046': ['0 0.119 0.267 0.091 0.329',
#   '0 0.311 0.18 0.082 0.359',
#   '0 0.037 0.415 0.075 0.31'],
#  'img_14045': ['0 0.117 0.272 0.098 0.306',
#   '0 0.321 0.184 0.076 0.368',
#   '0 0.039 0.423 0.078 0.269'],
#  'img_14044': ['0 0.043 0.432 0.087 0.236',
#   '0 0.11 0.286 0.099 0.289',
#   '0 0.339 0.182 0.081 0.365'],
#  'img_14043': ['0 0.044 0.445 0.088 0.236',
#   '0 0.362 0.18 0.095 0.359',
#   '0 0.107 0.308 0.098 0.234'],
#  'img_14042': ['0 0.045 0.444 0.089 0.255',
#   '0 0.112 0.328 0.092 0.193',
#   '0 0.364 0.186 0.102 0.372'],
#  'img_14041': ['0 0.045 0.444 0.089 0.255',
#   '0 0.112 0.345 0.092 0.188',
#   '0 0.374 0.188 0.09 0.375'],
#  'img_14040': ['0 0.046 0.437 0.091 0.255',
#   '0 0.112 0.345 0.092 0.188',
#   '0 0.399 0.19 0.068 0.38'],
#  'img_14039': ['0 0.046 0.437 0.091 0.255',
#   '0 0.112 0.345 0.092 0.188',
#   '0 0.42 0.191 0.078 0.382'],
#  'img_14038': ['0 0.046 0.439 0.091 0.255',
#   '0 0.433 0.196 0.101 0.391',
#   '0 0.113 0.345 0.092 0.188'],
#  'img_13981': ['0 0.032 0.117 0.065 0.234',
#   '0 0.422 0.172 0.058 0.343',
#   '0 0.359 0.365 0.101 0.48'],
#  'img_13980': ['0 0.349 0.362 0.096 0.494', '0 0.458 0.173 0.097 0.345'],
#  'img_13979': ['0 0.304 0.344 0.097 0.462', '0 0.484 0.178 0.097 0.356'],
#  'img_13978': ['0 0.292 0.349 0.119 0.452', '0 0.506 0.181 0.057 0.361'],
#  'img_13977': ['0 0.264 0.339 0.084 0.459', '0 0.55 0.18 0.105 0.359'],
#  'img_13976': ['0 0.563 0.177 0.103 0.354', '0 0.243 0.35 0.07 0.446'],
#  'img_13975': ['0 0.227 0.346 0.093 0.452', '0 0.594 0.18 0.064 0.361'],
#  'img_13974': ['0 0.21 0.335 0.087 0.462', '0 0.629 0.184 0.107 0.368'],
#  'img_13973': ['0 0.186 0.322 0.066 0.443', '0 0.642 0.181 0.11 0.363'],
#  'img_13972': ['0 0.17 0.311 0.097 0.439', '0 0.678 0.182 0.054 0.365'],
#  'img_13971': ['0 0.153 0.309 0.131 0.43', '0 0.72 0.192 0.11 0.384'],
#  'img_13970': ['0 0.153 0.303 0.123 0.439', '0 0.735 0.192 0.112 0.384'],
#  'img_13969': ['0 0.77 0.195 0.055 0.389', '0 0.134 0.301 0.113 0.443'],
#  'img_13968': ['0 0.113 0.295 0.093 0.45', '0 0.814 0.196 0.132 0.393'],
#  'img_13967': ['0 0.112 0.294 0.09 0.457', '0 0.839 0.196 0.109 0.391'],
#  'img_13966': ['0 0.106 0.29 0.081 0.457', '0 0.875 0.198 0.056 0.396'],
#  'img_13965': ['0 0.105 0.288 0.081 0.457', '0 0.92 0.223 0.125 0.404'],
#  'img_13964': ['0 0.934 0.224 0.133 0.409', '0 0.105 0.288 0.081 0.457'],
#  'img_13963': ['0 0.102 0.288 0.081 0.457'],
#  'img_13962': ['0 0.102 0.288 0.081 0.457'],
#  'img_13961': ['0 0.102 0.288 0.081 0.457'],
#  'img_13960': ['0 0.102 0.288 0.081 0.457'],
#  'img_13959': ['0 0.102 0.288 0.081 0.457'],
#  'img_13958': ['0 0.102 0.288 0.081 0.457'],
#  'img_13957': ['0 0.102 0.288 0.081 0.457'],
#  'img_13956': ['0 0.102 0.288 0.081 0.457'],
#  'img_13955': ['0 0.102 0.288 0.081 0.457'],
#  'img_13954': ['0 0.102 0.288 0.081 0.457'],
#  'img_13953': ['0 0.102 0.288 0.081 0.457'],
#  'img_13952': ['0 0.102 0.288 0.081 0.457'],
#  'img_13951': ['0 0.102 0.29 0.081 0.457'],
#  'img_13950': ['0 0.098 0.29 0.081 0.457'],
#  'img_13949': ['0 0.098 0.29 0.081 0.457'],
#  'img_13948': ['0 0.098 0.29 0.081 0.457'],
#  'img_13947': ['0 0.098 0.29 0.081 0.457'],
#  'img_13946': ['0 0.098 0.29 0.081 0.457'],
#  'img_13945': ['0 0.098 0.295 0.081 0.457'],
#  'img_13944': ['0 0.1 0.292 0.081 0.457'],
#  'img_13943': ['0 0.102 0.293 0.079 0.444'],
#  'img_13942': ['0 0.973 0.113 0.054 0.226', '0 0.1 0.289 0.08 0.455'],
#  'img_13941': ['0 0.972 0.124 0.057 0.248', '0 0.101 0.293 0.077 0.455'],
#  'img_13940': ['0 0.102 0.295 0.078 0.455', '0 0.971 0.119 0.054 0.239'],
#  'img_13939': ['0 0.971 0.121 0.058 0.242', '0 0.103 0.295 0.079 0.453'],
#  'img_13938': ['0 0.103 0.295 0.076 0.446', '0 0.969 0.132 0.06 0.264'],
#  'img_13937': ['0 0.971 0.136 0.058 0.272', '0 0.102 0.297 0.074 0.46'],
#  'img_13936': ['0 0.104 0.297 0.07 0.436', '0 0.973 0.134 0.054 0.267'],
#  'img_13935': ['0 0.974 0.14 0.052 0.28', '0 0.105 0.302 0.079 0.444'],
#  'img_13934': ['0 0.105 0.303 0.075 0.448', '0 0.977 0.145 0.047 0.29'],
#  'img_13933': ['0 0.976 0.149 0.049 0.297', '0 0.108 0.3 0.069 0.43'],
#  'img_13932': ['0 0.977 0.147 0.047 0.294', '0 0.104 0.311 0.074 0.427'],
#  'img_13931': ['0 0.095 0.307 0.076 0.398', '0 0.978 0.157 0.044 0.313'],
#  'img_13930': ['0 0.089 0.308 0.079 0.393', '0 0.976 0.155 0.049 0.31'],
#  'img_13929': ['0 0.09 0.326 0.085 0.368', '0 0.974 0.16 0.052 0.32'],
#  'img_13928': ['0 0.096 0.341 0.108 0.331', '0 0.979 0.173 0.043 0.345'],
#  'img_13927': ['0 0.98 0.179 0.04 0.357', '0 0.102 0.352 0.122 0.315'],
#  'img_13926': ['0 0.92 0.134 0.074 0.269',
#   '0 0.108 0.365 0.123 0.282',
#   '0 0.973 0.175 0.055 0.35'],
#  'img_13925': ['0 0.109 0.364 0.116 0.296',
#   '0 0.911 0.13 0.062 0.26',
#   '0 0.97 0.181 0.06 0.361'],
#  ...}

# %% [markdown]
# ## only save label files

# %%
# save_path = '/local_hdd/works/ICRyu_workspace/for_yolo/for_hrnet/label_1'
save_path = '/local_hdd/works/ICRyu_workspace/for_yolo/for_hrnet/label_2'

# %%
for key in data:
    with open(os.path.join(save_path, "".join([key, ".txt"])), 'w') as output_txt_file:
        for each_anno in data[key]:
            output_txt_file.write(each_anno + '\n')

# %% [markdown]
# ## 파일저장

# %%
json_path = '/local_hdd/works/ICRyu_workspace/for_yolo/dataset/data1/label_1/nh.json'
manifest_path = '/local_hdd/works/ICRyu_workspace/for_yolo/dataset/data1/manifest.txt'
img_path = '/local_hdd/works/ICRyu_workspace/for_yolo/dataset/data1/target_label_for_NH/1~15000/'
img_type = '.png'
save_path = '/local_hdd/works/ICRyu_workspace/for_yolo/dataset/data1/label_1_converted/'
# save_path = '/local_hdd/works/ICRyu_workspace/for_yolo/dataset/data1/label_1_converted/'

# json_path = '/local_hdd/works/ICRyu_workspace/for_yolo/dataset/data1/label_1/ai-hub.json'
# manifest_path = '/local_hdd/works/ICRyu_workspace/for_yolo/dataset/data1/manifest_2.txt'
# img_path = '/local_hdd/works/ICRyu_workspace/for_yolo/dataset/data1/target_label_for_NH/15001~30000/'
# img_type = '.jpg'
# save_path = '/local_hdd/works/ICRyu_workspace/for_yolo/dataset/data1/label_1_converted_2/'

# %%
if os.path.isdir(manifest_path):
    manifest_abspath = os.path.join(manifest_path, "manifest.txt")
else:
    manifest_abspath = manifest_path

with open(os.path.abspath(manifest_abspath), "w") as manifest_file:

    for key in data:
        manifest_file.write(os.path.abspath(os.path.join(
            img_path, "".join([key, img_type, "\n"]))))

        with open(os.path.abspath(os.path.join(save_path, "".join([key, ".txt"]))), "w") as output_txt_file:
            for each_anno in data[key]:
                output_txt_file.write(each_anno+'\n')

# %% [markdown]
# ## label 없는 이미지삭제하기

# %%
label_file_name_list = list(data.keys())

# %%
image_file_name_list = os.listdir(img_path)

# %%
no_label_imgs_list = []

for each_img in image_file_name_list:
    if each_img.split('.')[0] not in label_file_name_list:
        no_label_imgs_list.append(each_img)

# %%
len(no_label_imgs_list)
# Out:
# 53

# %%
no_label_imgs_list[0]
# Out:
# 'img_29435.jpg'

# %%
os.path.join(img_path, no_label_imgs_list[0])
# Out:
# '/local_hdd/works/ICRyu_workspace/for_yolo/dataset/data1/target_label_for_NH/15001~30000/img_29435.jpg'

# %%
for i in no_label_imgs_list:
    os.remove(os.path.join(img_path, i))

# %% [markdown]
# ## class 합치기
